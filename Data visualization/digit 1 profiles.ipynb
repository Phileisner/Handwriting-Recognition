# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import glob
import io
import seaborn

# %%
path1_1="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 1/digit1try1/20200728_155227_Accelerometer.csv"

# %%
df1_1= pd.read_csv(path1_1, skiprows=4 )

# %%
import seaborn as sns; sns.set(color_codes = True)

g1_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mg)", data = df1_1)

# %%
import seaborn as sns; sns.set(color_codes = True)

g1_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mg)", data = df1_1)

# %%
import seaborn as sns; sns.set(color_codes = True)

g1_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mg)", data = df1_1)

# %%
acc_1= df1_1['X (mg)']**2 + df1_1['Y (mg)']**2 + df1_1['Z (mg)']**2
acc_1= np.sqrt(acc_1)

# %%
import seaborn as sns; sns.set(color_codes = True)

g1_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Acc", data = df1_1)

# %%
#Gyro

# %%
path1_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 1/digit1try1/20200728_155227_Gyroscope.csv"

# %%
df1_2= pd.read_csv(path1_2, skiprows=4 )

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (dps)", data = df1_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (dps)", data = df1_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (dps)", data = df1_2)

# %%
GYR_1= df1_2['X (dps)']**2 + df1_2['Y (dps)']**2 + df1_2['Z (dps)']**2
GYR_1= np.sqrt(GYR_1)

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df1_2)

# %%
#Magnetometer data profile

# %%
path1_3="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 1/digit1try1/20200728_155227_Magnetometer.csv"

# %%
df1_3= pd.read_csv(path1_3, skiprows=4 )

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mGa)", data = df1_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mGa)", data = df1_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mGa)", data = df1_3)

# %%
#Create new features for digit data
MAG_1= df1_3['X (mGa)']**2 + df1_3['Y (mGa)']**2 + df1_3['Z (mGa)']**2
MAG_1= np.sqrt(MAG_1)

# %%
import seaborn as sns; sns.set(color_codes = True)
g1_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "MAG", data = df1_3)
