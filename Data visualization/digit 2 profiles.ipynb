# %%
#Accleration profile

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import glob
import io
import seaborn

# %%
path2_1="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 2/digit2try1/20200728_161748_Accelerometer.csv"

# %%
df2_1= pd.read_csv(path2_1, skiprows=4 ) 
df2_1.head()
# Out:
#                       Date  HostTimestamp (ms)         NodeName  \
# 0  28/07/2020 16:19:41.839                  39  AM1V310 @34264E
# 1  28/07/2020 16:19:41.867                  74  AM1V310 @34264E
# 2  28/07/2020 16:19:41.929                 130  AM1V310 @34264E
# 3  28/07/2020 16:19:41.989                 186  AM1V310 @34264E
# 4  28/07/2020 16:19:42.017                 224  AM1V310 @34264E
#
#    NodeTimestamp       RawData  X (mg)  Y (mg)  Z (mg)          Acc
# 0          61929  C8FC78FF30FE    -824    -136    -464   955.388926
# 1          61935  52FCA8FF44FE    -942     -88    -444  1045.104779
# 2          61941  C7FCC7FF02FE    -825     -57    -510   971.583244
# 3          61947  9AFC9DFF0FFE    -870     -99    -497  1006.831664
# 4          61954  CBFCB4FF36FE    -821     -76    -458   943.176018

# %%
#Create new features for digit data
acc_2= df2_1['X (mg)']**2 + df2_1['Y (mg)']**2 + df2_1['Z (mg)']**2
acc_2= np.sqrt(acc_2)

# %%
HostTime = df3_1['HostTimestamp (ms)']
HostTime -= HostTime[0]
HostTime /= 1000

# %%
import seaborn as sns; sns.set(color_codes = True)
g2_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Acc", data = df2_1)

# %%
#Gyroscope profile

# %%
path2_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 2/digit2try1/20200728_161748_Gyroscope.csv"

# %%
df2_2 = pd.read_csv(path2_2, skiprows=4)

# %%
#Create new features for digit data

GYR_2= df2_2['X (dps)']**2 + df2_2['Y (dps)']**2 + df2_2['Z (dps)']**2
GYR_2= np.sqrt(GYR_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g2_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df2_2)

# %%
#Magnetometer data profile

# %%
path2_3="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 2/digit2try1/20200728_161748_Magnetometer.csv"

# %%
df2_3 = pd.read_csv(path2_3, skiprows=4 )

# %%
#Create new features for digit data
MAG_2= df2_3['X (mGa)']**2 + df2_3['Y (mGa)']**2 + df2_3['Z (mGa)']**2
MAG_2= np.sqrt(MAG_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g2_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "MAG", data = df2_3)
