# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import glob
import io
import seaborn

# %%
path0_1="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 0/digit0try1/20200728_144234_Accelerometer.csv"

# %%
df0_1= pd.read_csv(path0_1, skiprows=4 )

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mg)", data = df0_1)

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mg)", data = df0_1)

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mg)", data = df0_1)

# %%
acc_0= df0_1['X (mg)']**2 + df0_1['Y (mg)']**2 + df0_1['Z (mg)']**2
acc_0= np.sqrt(acc_0)

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Acc", data = df0_1)

# %%
#Gyro

# %%
path0_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 0/digit0try1/20200728_144234_Gyroscope.csv"

# %%
df0_2= pd.read_csv(path0_2, skiprows=4 )

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (dps)", data = df0_2)

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (dps)", data = df0_2)

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (dps)", data = df0_2)

# %%
GYR_0= df0_2['X (dps)']**2 + df0_2['Y (dps)']**2 + df0_2['Z (dps)']**2
GYR_0= np.sqrt(GYR_0)

# %%
import seaborn as sns; sns.set(color_codes = True)

g0_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df0_2)

# %%
#Magnetometer data profile

# %%
path0_3="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 0/digit0try1/20200728_144234_Magnetometer.csv"

# %%
path0_3
df0_3= pd.read_csv(path0_3, skiprows=4 )

# %%
#Create new features for digit data
MAG_0= df0_3['X (mGa)']**2 + df0_3['Y (mGa)']**2 + df0_3['Z (mGa)']**2
MAG_0= np.sqrt(MAG_0)

# %%
import seaborn as sns; sns.set(color_codes = True)
g0_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mGa)", data = df0_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g0_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mGa)", data = df0_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g0_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mGa)", data = df0_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g0_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "MAG", data = df0_3)
