# %%
#Acceleration profiles

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import glob
import io
import seaborn

# %%
path4_1="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 4/Digit4try1_Accelerometer.csv"

# %%
df4_1 = pd.read_csv(path4_1, skiprows=3 )

# %%
#Create new features for digit 4 data
acc_4= df4_1['X (mg)']**2 + df4_1['Y (mg)']**2 + df4_1['Z (mg)']**2
acc_4= np.sqrt(acc_4)

# %%
import seaborn as sns; sns.set(color_codes = True)
g4_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Acc", data = df4_1)

# %%
#Gyroscope profiles

# %%
path4_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 4/Digit4try1_Gyroscope.csv"

# %%
df4_2 = pd.read_csv(path4_2, skiprows=3)

# %%
#Create new features for digit 4 data
GYR_4= df4_2['X (dps)']**2 + df4_2['Y (dps)']**2 + df4_2['Z (dps)']**2
GYR_4= np.sqrt(GYR_4)

# %%
import seaborn as sns; sns.set(color_codes = True)
g4_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df4_2)

# %%
#Magnetometer profiles

# %%
path4_3="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 4/Digit4try1_Magnetometer.csv"

# %%
df4_3 = pd.read_csv(path4_3, skiprows=3 )

# %%
#Create new features for digit 4 data
MAG_4= df4_3['X (mGa)']**2 + df4_3['Y (mGa)']**2 + df4_3['Z (mGa)']**2
MAG_4= np.sqrt(MAG_4)

# %%
import seaborn as sns; sns.set(color_codes = True)
g4_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "MAG", data = df4_3)
