# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import glob
import io
import seaborn

# %%
#ACCELERATION

# %%
path7_1="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 7/Digit7try1_Accelerometer.csv"

# %%
df7_1 = pd.read_csv(path7_1, skiprows=3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mg)", data = df7_1)

# %%
g7_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mg)", data = df7_1)

# %%
g7_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mg)", data = df7_1)

# %%
#Create new features for digit 6 data
acc_7= df7_1['X (mg)']**2 + df7_1['Y (mg)']**2 + df7_1['Z (mg)']**2
acc_7= np.sqrt(acc_7)

# %%
g7_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Acc", data = df7_1)

# %%
#GYRO SCOPE

# %%
path7_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 7/Digit7try1_Gyroscope.csv"

# %%
df7_2 = pd.read_csv(path7_2, skiprows=3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (dps)", data = df7_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (dps)", data = df7_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (dps)", data = df7_2)

# %%
#Create new features for digit 6 data
GYR_7= df7_2['X (dps)']**2 + df7_2['Y (dps)']**2 + df7_2['Z (dps)']**2
GYR_7= np.sqrt(GYR_7)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df7_2)

# %%
#MAGNETOMETER DATA

# %%
path7_3="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 7/Digit7try1_Magnetometer.csv"

# %%
df7_3 = pd.read_csv(path7_3, skiprows=3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mGa)", data = df7_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mGa)", data = df7_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mGa)", data = df7_3)

# %%
#Create new features for digit 7 data
MAG_7= df7_3['X (mGa)']**2 + df7_3['Y (mGa)']**2 + df7_3['Z (mGa)']**2
MAG_7= np.sqrt(MAG_7)

# %%
import seaborn as sns; sns.set(color_codes = True)
g7_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "MAG", data = df7_3)
