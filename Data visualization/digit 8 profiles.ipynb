# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import glob
import io
import seaborn

# %%
#ACCELERATION

# %%
path8_1="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 8/Digit8try1_Accelerometer.csv"

# %%
df8_1 = pd.read_csv(path8_1, skiprows=3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mg)", data = df8_1)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mg)", data = df8_1)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mg)", data = df8_1)

# %%
#Create new features for digit 8 data
acc_8= df8_1['X (mg)']**2 + df8_1['Y (mg)']**2 + df8_1['Z (mg)']**2
acc_8= np.sqrt(acc_8)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_1 = sns.lineplot(x= "HostTimestamp (ms)", y = "Acc", data = df8_1)

# %%
#GYROSCOPE DATA

# %%
path8_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 8/Digit8try1_Gyroscope.csv"

# %%
df8_2 = pd.read_csv(path8_2, skiprows=3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (dps)", data = df8_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (dps)", data = df8_2)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (dps)", data = df8_2)

# %%
#Create new features for digit 8 data
GYR_8= df8_2['X (dps)']**2 + df8_2['Y (dps)']**2 + df8_2['Z (dps)']**2
GYR_8= np.sqrt(GYR_8)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df8_2)

# %%
#MAGNETOMETER DATA

# %%
path8_3="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 8/Digit8try1_Magnetometer.csv"

# %%
df8_3 = pd.read_csv(path8_3, skiprows=3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "X (mGa)", data = df8_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Y (mGa)", data = df8_3)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "Z (mGa)", data = df8_3)

# %%
#Create new features for digit 8 data
MAG_8= df8_3['X (mGa)']**2 + df8_3['Y (mGa)']**2 + df8_3['Z (mGa)']**2
MAG_8= np.sqrt(MAG_8)

# %%
import seaborn as sns; sns.set(color_codes = True)
g8_3 = sns.lineplot(x= "HostTimestamp (ms)", y = "MAG", data = df8_3)
