# %%
#This section is a visual comparision of Gyro data of digit 2 3 4 5 6

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
import glob
import io
import seaborn

# %%
path2_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 2/digit2try1/20200728_161748_Gyroscope.csv"
path3_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/Digit 3/Digit3try1_Gyroscope.csv"
path4_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 4/Digit4try1_Gyroscope.csv"
path5_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 5/Digit5try1_Gyroscope.csv"
path6_2="/Users/nhannguyen/Downloads/Wearble Project/Organized Data/digit 6/Digit6try1_Gyroscope.csv"

# %%
df2_2 = pd.read_csv(path2_2, skiprows=4)
df3_2 = pd.read_csv(path3_2, skiprows=3) 
df4_2 = pd.read_csv(path4_2, skiprows=3) 
df5_2 = pd.read_csv(path5_2, skiprows=3)
df6_2 = pd.read_csv(path6_2, skiprows=3)

# %%
#Create new features for digit data

GYR_2= df2_2['X (dps)']**2 + df2_2['Y (dps)']**2 + df2_2['Z (dps)']**2
GYR_2= np.sqrt(GYR_2)

GYR_3= df3_2['X (dps)']**2 + df3_2['Y (dps)']**2 + df3_2['Z (dps)']**2
GYR_3= np.sqrt(GYR_3)

#Create new features for digit 4 data
GYR_4= df4_2['X (dps)']**2 + df4_2['Y (dps)']**2 + df4_2['Z (dps)']**2
GYR_4= np.sqrt(GYR_4)

#Create new features for digit 5 data
GYR_5= df5_2['X (dps)']**2 + df5_2['Y (dps)']**2 + df5_2['Z (dps)']**2
GYR_5= np.sqrt(GYR_5)

#Create new features for digit 6 data
GYR_6= df6_2['X (dps)']**2 + df6_2['Y (dps)']**2 + df6_2['Z (dps)']**2
GYR_6= np.sqrt(GYR_6)

# %%
HostTime = df3_2['HostTimestamp (ms)']
HostTime -= HostTime[0]
HostTime *= 1000

# %%
#Visual comparison for GYRO profiles of digit 3, 4, 5, 6
import seaborn as sns; sns.set(color_codes = True)
g2_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df2_2)
g3_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df3_2)
g4_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df4_2)
g5_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df5_2)
g6_2 = sns.lineplot(x= "HostTimestamp (ms)", y = "GYR", data = df6_2)
plt.legend('23456', ncol=2, loc='upper right');
